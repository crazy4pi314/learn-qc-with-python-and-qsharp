# %% [markdown]
# # [Learn Quantum Computing with Python and Q#](https://www.manning.com/books/learn-quantum-computing-with-python-and-q-sharp?a_aid=learn-qc-granade&a_bid=ee23f338)<br>8 | Quantum sensing: It's not just a phase
# ---

# %%
# %matplotlib inline

# %run host.py
# Out:
# Pssst the hidden angle is 1.0237442798950094, good luck!
# The hidden angle you think was [1.02658221]!
# Pssst the hidden angle is 1.4875701722519485, good luck!
# The hidden angle you think was [1.48168477]!

# %%
qsharp.component_versions()
# Out:
# {'iqsharp': LooseVersion ('0.12.20070124'),
#  'Jupyter Core': LooseVersion ('1.4.0.0'),
#  '.NET Runtime': LooseVersion ('.NETCoreApp,Version=v3.1'),
#  'qsharp': LooseVersion ('0.12.2007.124')}
